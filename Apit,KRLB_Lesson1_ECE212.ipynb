# %% [markdown]
# # Module 1: The Way of the Programming

# %% [markdown]
# ## Introduction

# %% [markdown]
# The goal of this coursepack is to teach you to understand and create computer programs in Python. At the beginning of each chapter, we will outline for you the learning goals and objectives that should be accomplished once you have gone through the chapter.
#
# Understanding computer programs requires algorithmic, mechanistic thinking. Programs specify mechanistic sequences of actions to perform; when executed, they transform input data into output data. They execute very reliably, and very fast, but not creatively. Computers do what you tell them to do, not what you mean for them to do. Thus, understanding computer code involves a lot of mental simulation of what will actually happen, not what you wish would happen.
#
# Writing computer programs requires not only mechanistic thinking but creative problem solving. Problem solving means the ability to formulate problems, think creatively about solutions, and express a solution clearly and accurately. As it turns out, the process of learning to program is an excellent opportunity to practice problem solving skills.

# %% [markdown]
# # Activity

# %% [markdown]
# *1. Why do you think uderstanding computer programs is relevant in our time today especially in the new normal?*
#
# Computer programs are very relevant at this time, because our generation are really into technologies, whatever we may use it includes computer programmings. Wherever we go we use technologies, especially now, we are really into gadgets: phones, laptops, machines and other high technologies. Because it makes our life easier in all things.
#
# *2. If you were able to learn computer program what program will you code? Why?*
#
# If i would be able to learn computer program, I would like to code with Python. Based on experienced and forseeing, python is more in demand in programming and is more accessible, I mean the language for what I've heard pythons language is more easier. And I want to program robots(??) or machines or techs, not so sure, but I'm interested.
#
# *3. What would be your primary motivation in learning programming?*
#
# My primary motivation is knowing that programming will be able to make you more money if you are a pro, especially using python or java. Also, because this is one of our subject this semester.

# %% [markdown]
# ## The Python Programming Language

# %% [markdown]
# I will be learning python, and it is considered as a high level language in programming. there are also low-level languages and computers can only execute programs in low-level languages.
#
# A high level language is more easier to program, less time to write for it is shorter and easier to read. Also, it is portable but the processing of a high level languages takes some time, in which considered as its disadvantage.

# %% [markdown]
# **Two kinds of programs that process high-level languages into low-level languages:**
#
# **1. *Interpreters*-** reads a high level program and executes, itdoes what the program says, alternately reading lines and performing computations.
#
# **2. *Compiler*-** reads the program and translates before running.
#
# High-level program is called the **source code**.
#
# Translated program is called **object code/executable**.
#
# First compiled into a lower level language is called **byte code**.
#
# The interpreted by a program is called **virtual machine**.

# %% [markdown]
# ### More About Programs

# %% [markdown]
# ***Program*** is a sequence of instruction that specifies how to perform a computation.
#
# ***Input*-** Get the data from the keyboard, a file, or some other device.
#
# ***Output*-** Displays data on the screen or send the data to a file or to other devices.
#
# ***Math & Logic*-** Perform basic mathematical ooperations like **+** and ***** and logical operations like ***and, or,*** and ***not*.**
#
# ***Conditional Execution*-** Check  for certain conditions and execute the appropriae sequence statements.
#
# ***Repetition*-** Perform some action repeatedly, usually with some variation.

# %% [markdown]
# ### Review of Control Structures

# %% [markdown]
# For Loop Example:

# %%
for character in "KARL":
 print(character)
# Out:
# K
# A
# R
# L

# %% [markdown]
# While Loop Example:

# %%
grocery_item = ""
while grocery_item != "done":
    grocery_item = input("Please write down an item to add to your grocery list. When you are done writing the list simply type: done")
    print(grocery_item)
# Out:
# Please write down an item to add to your grocery list. When you are done writing the list simply type: donesprite
# sprite
# Please write down an item to add to your grocery list. When you are done writing the list simply type: donecheezy
# cheezy
# Please write down an item to add to your grocery list. When you are done writing the list simply type: donecornrice
# cornrice
# Please write down an item to add to your grocery list. When you are done writing the list simply type: donedone
# done

# %% [markdown]
# Conditionals Example:

# %%
grocery_item = ""
grocery_list = []
while grocery_item != "done":
    grocery_item = input("Please write down an item to add to your grocery list. When you are done writing the list then simply type: done")
    if grocery_item == 'done':
        continue
    else:
        print("adding the item to the list")
        grocery_list.append(grocery_item)
    print("Here is our grocery list:")
    print(grocery_list)
# Out:
# Please write down an item to add to your grocery list. When you are done writing the list then simply type: donemeat
# adding the item to the list
# Here is our grocery list:
# ['meat']
# Please write down an item to add to your grocery list. When you are done writing the list then simply type: donefish
# adding the item to the list
# Here is our grocery list:
# ['meat', 'fish']
# Please write down an item to add to your grocery list. When you are done writing the list then simply type: doneeggs
# adding the item to the list
# Here is our grocery list:
# ['meat', 'fish', 'eggs']
# Please write down an item to add to your grocery list. When you are done writing the list then simply type: donehotdogs
# adding the item to the list
# Here is our grocery list:
# ['meat', 'fish', 'eggs', 'hotdogs']
# Please write down an item to add to your grocery list. When you are done writing the list then simply type: donedone

# %% [markdown]
# ### Formal and Natural Languages

# %% [markdown]
# ***Natural Languages*-** Languages that people speak. Not designed by people.
#
# ***Formal Languages*-** Languages designed by people for specific applications.
#
# Programming languages belongs to ***formal languages*** for it have been designed to express computations.
#
# Formal languages tend to have strict rules about syntax.
#  ***Tokens*-** the basic elements of language: words, numbers,& chemical elements
#
#  ***Structure*-** the way tokens are arranged
#
#  ***Parsing*-** to figure out what the structure of the sentence
#
#  ***Semantics*-** to figure out what it means
#
# Formal and natural languages have many features in common— tokens, structure, syntax, and semantics — there	are	many differences:
#
# 1.***Ambiguity*-**
#
# **Natural languages=** full of ambiguity; using contextual clues
#
# **Formal languages*=** unambiguous;statement has exactlt one meaning
#
# 2.***Redundancy*-** Formal languages are less redundant and more concise
#
# 3.***Literalness*-**
#
# **Natural languages=** full of idiom and metaphor
#
# **Formal languages*=** mean exactly what they say
#
# 4.***Poetry*-** whole poem together	 creates an effect or emotional	 response.
#
# 5.***Prose*-** The literal meaning of words is more important, and the structure contributes more meaning.
#
# 6.***Program*-** The meaning of a computer program is unambiguous and literal, and	can	be	understood entirely by	analysis of	the	tokens	and	structure.

# %% [markdown]
# ### 1.4 A Typical First Program

# %% [markdown]
# The	first program written in a new language	is called ***Hello, World!***

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ### Comments

# %% [markdown]
# A **comment** is a computer program is text that is intended only for human reader. The **#** token starts a comment.

# %%
#
# This demo program shows off how elegant Python is!
# Written by Joe Soap, December 2010.
# Anyone mey freely copy or modify this program.
#

print("Hello, World!") # Isn't this easy!
# Out:
# Hello, World!

# %% [markdown]
# # APPLICATION

# %% [markdown]
# #### Ask Yourself:

# %% [markdown]
# *1. Why do you think Python is the most applicable programming language for scientific computing?*
#
# Python is the language for scientific computing because it is a high-level language. It is more portable, shorter and easier to be stock in mind for its imple programming syntax. As for my experienced in other language the C++, for me, it hardens me to understand the language because it is more complicated than using language in python.
#
# *2.f Python can build anything, where do you think Python is not applicable for?
#
# I think it is not capable for low-level devices.

# %% [markdown]
# ### Exercise 1: Mailing Address (Solved, 9 Lines)
#
#
# Create a program that displays your name and complete mailing address. The address should be printed in the format that is normally used in the area where you live. Your program does not need to read any input from the user.

# %%
print("Complete Name: Karl Roge Leen B. Apit")
print("Complete Address: Purok 11, Brgy. Mipangi, Nabunturan, Davao de Oro, Philippines, 8800")
print("Course: Bachelor of Science in Electronics Engineering")
print("School: University of Southeastern Philippines- Obrero Campus")
# Out:
# Complete Name: Karl Roge Leen B. Apit
# Complete Address: Purok 11, Brgy. Mipangi, Nabunturan, Davao de Oro, Philippines, 8800
# Course: Bachelor of Science in Electronics Engineering
# School: University of Southeastern Philippines- Obrero Campus

# %% [markdown]
# ### Exercise 2: Area of Room (solved, 13 Lines)
#
# Write a program that asks the user to enter the width and length of a room. Once these values have been read, your program should compute and display the area of the room. The length and the width will be entered as floating-point numbers. Include
# units in your prompt and output message; either feet or meters, depending on which unit you are more comfortable working with

# %%
#Compute the Area of the room
length = float(input("Enter the desired length of the room in ft.: "))
width = float(input("Enter the desired width of the room in ft.: "))

area = length * width

print("The area of the room is",area, "square feet.")
# Out:
# Enter the desired length of the room in ft.: 12
# Enter the desired width of the room in ft.: 12
# The area of the room is 144.0 square feet.

# %% [markdown]
# ### Exercise 3: Arithmetic (solve, 22 lines)
#
# Create a program that reads two integers, a and b, from the user. Your program should
# compute and display:
#
#     •The sum of a and b
#     •The difference when b is subtracted from a
#     •The product of a and b
#     •The quotient when a is divided by b
#     •The remainder when a is divided by b
#     •The result of log10 a
#     •The result of log ab

# %%
#The sum of a and b
print("Enter two integers you want to add")

a = float(input("Enter any integer: "))
b = float(input("Enter any integer: "))

sum = a + b

print("The sum of the two integers is", sum)
# Out:
# Enter two integers you want to add
# Enter any integer: 3
# Enter any integer: 7
# The sum of the two integers is 10.0

# %%
#The difference when b is subtracted from a
print("Enter two integers you want to subtract")

b = float(input("Enter any integer value for b: "))
a = float(input("Enter any integer value for a: "))

difference = b - a

print("The difference of b - a is", difference)
# Out:
# Enter two integers you want to subtract
# Enter any integer value for b: 7
# Enter any integer value for a: 3
# The difference of b - a is 4.0

# %%
#The product of a and b
print("Enter two integers you want to multiply")

a = float(input("Enter any integer: "))
b = float(input("Enter any integer: "))

product = a * b

print("The product of the two integers is", product)
# Out:
# Enter two integers you want to multiply
# Enter any integer: 3
# Enter any integer: 7
# The product of the two integers is 21.0

# %%
#The quotient when a is divided by b
print("Enter two integers you want to divide")

a = float(input("Enter any integer value for a: "))
b = float(input("Enter any integer value for b: "))

quotient = a/b

print("The quotient of a/b is", quotient)
# Out:
# Enter two integers you want to divide
# Enter any integer value for a: 70
# Enter any integer value for b: 10
# The quotient of a/b is 7.0

# %%
#The remainder when a is divided by b
print("Enter two integers you want to divide and the remainder will be shown to you")

a = float(input("Enter your Dividend: "))
b = float(input("Enter your Divisor: "))

remainder = a % b

print("The remainder of the quotient is", remainder)
# Out:
# Enter two integers you want to divide and the remainder will be shown to you
# Enter your Dividend: 30
# Enter your Divisor: 13
# The remainder of the quotient is 4.0

# %%
#The result of log10 a
print("Enter any integer that you want to solve for its logarithm")

a = float(input("Enter any integer for a: "))

import math

math.log10( a )

print("math.log10(a) is", math.log10(a))
# Out:
# Enter any integer that you want to solve for its logarithm
# Enter any integer for a: 7
# math.log10(a) is 0.8450980400142568

# %%
#The result of log ab
print("Enter any integer for a and b")

a = float(input("integer a: "))
b = float(input("integer b: "))

import math
math.log10(a*b)

print("math.log10(a*b) is", math.log10(a*b))
# Out:
# Enter any integer for a and b
# integer a: 27
# integer b: 3
# math.log10(a*b) is 1.9084850188786497

# %% [markdown]
# ### Exercise 4: Area and Volume (15 lines)
#
# Write a program that begins by reading a radius, r, from the user. The program will continue by computing and displaying the area of a circle with radius r and the volume of a sphere with radius r. Use the pi constant in the math module in your
# calculations.

# %%
print("Enter any radius")

import math
r = float(input("Enter any radius for r in meters: "))

area = math.pi * r * r 
volume = (4/3) * math.pi * r * r * r

print("The area of a circle with radius r is",area,"meter-squared")
print("The volume of a sphere with a radius r is", volume,"cubic meter")
# Out:
# Enter any radius
# Enter any radius for r in meters: 7
# The area of a circle with radius r is 153.93804002589985 meter-squared
# The volume of a sphere with a radius r is 1436.755040241732 cubic meter
